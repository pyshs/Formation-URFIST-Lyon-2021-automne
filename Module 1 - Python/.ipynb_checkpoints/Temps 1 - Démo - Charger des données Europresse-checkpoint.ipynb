# %% [markdown]
# ## Un exemple de pratique "discrète" : récupération d'un jeu de données extérieures, ici sur la plateforme Europresse
#
# https://paris-sorbonne.libguides.com/europresse_version-classique
#
# Mot-clé : TEXT= chloroquine | hydroxychloroquine

# %% [markdown]
# #### Chargement de bibliothèques

# %%
import pandas as pd
import bs4 as bs
import regex as re
import datetime
import os
import matplotlib.pyplot as plt

#install lxml

# %matplotlib inline

# %% [markdown]
# #### Définition de fonctions

# %%
def extract(file): 
    """
    Extraction de données d'une page Europesse
    """
    corpus_html = bs.BeautifulSoup(open(file, encoding="utf8"),"lxml")    
    corpus = [] #tableau que l'on va remplir avec les données
    for i in corpus_html.find_all("article"):
        
        #on regarde s'il y a un titre dans l'article
        try:
            titre = i.find("div",{"class":"titreArticle"}).text 
        except:
            titre = None #sinon on renvoie rien
            
        #Pareil pour la date/header
        try:
            header = i.find("span",{"class":"DocHeader"}).text
        except:
            header = None
        
        #Le nom de la publicatoin
        try:
            publication = i.find("span",{"class":"DocPublicationName"}).text
        except:
            publication = None
         
        #le contenu
        try:
            text = i.find("div",{"class":"DocText clearfix"}).text
        except:
            text = None
            
        #le contenu
        try:
            auteur = i.find("div",{"class":"docAuthors"}).text
        except:
            auteur = None
            
        #On ajoute ces éléments au corpus
        corpus.append([header,titre,publication,text,auteur])
        
    return corpus #On renvoie les informations


def reco_date(x):
    """
    Recoder la date telle que présente dans un fichier europresse
    """
    mois = {"janvier":"01","février":"02","mars":"03",
            "avril":"04","mai":"05","juin":"06","juillet":"07",
            "août":"08","septembre":"09","octobre":"10","novembre":"11","décembre":"12"}
    
    t = re.findall("\w+ \w+ [0-9]{4}",x)
    
    if len(t) <1:
        return None

    t = t[0]
    
    for i in mois:
        if i in t:
            t = t.replace(i,"/%s/"%mois[i]).replace(" ","")

    t = datetime.datetime.strptime(t,"%d/%m/%Y")
            
    return t

# %% [markdown]
# #### Chargement des données et mise en forme

# %%
corpus = extract("./Data/biblioeuropresse20211005063330.HTML")
corpus = pd.DataFrame(corpus)
corpus.columns = ["Date","Titre","Journal","Contenu","Auteur"]
corpus["Date_reco"] = corpus["Date"].apply(reco_date)
corpus["Date_reco"] = pd.to_datetime(corpus["Date_reco"])
corpus = corpus.set_index("Date_reco")
corpus
# Out:
#                                                          Date  \
# Date_reco
# 2021-07-06   Le Figaro,  mardi 6 juillet 2021 1674 mots, p...
# 2020-12-08   Analyses,  mardi 8 décembre 2020 1140 mots, p...
# 2020-10-15            jeudi 15 octobre 2020 2310 mots, p. 12
# 2020-11-14   _Société,  samedi 14 novembre 2020 455 mots, ...
# 2020-11-13     vendredi 13 novembre 2020 2161 mots, p. 2,3,4
# ...                                                       ...
# 2021-01-12   Evénement,  mardi 12 janvier 2021 129 mots, p...
# 2021-02-15   _Politique,  lundi 15 février 2021 639 mots, ...
# 2021-03-12             vendredi 12 mars 2021 544 mots, p. 14
# 2021-02-05   _Société,  vendredi 5 février 2021 400 mots, ...
# 2021-04-10   Le Figaro,  samedi 10 avril 2021 889 mots, p. 9
#
#                                                         Titre  \
# Date_reco
# 2021-07-06   Bolsonaro sur le banc des accusés après les r...
# 2020-12-08   Gilbert Deray Bilan d'étape du virus, un an a...
# 2020-10-15   Information et pandémie Les médias traitent-i...
# 2020-11-14       Par Nicolas Berrod, Ludwig Gallet et Paméla
# 2020-11-13   Covid-19 : le docu «Hold-up» bat des records ...
# ...                                                       ...
# 2021-01-12   Repères Vaccins sous surveillance. Dix ans de...
# 2021-02-15   Le médecin-chef de la macronie Nommé au gouve...
# 2021-03-12       Attaqué de partout, Didier Raoult s'en fout
# 2021-02-05      Elsa Mari et Florence Méréo L'innovation Les
# 2021-04-10   Ces professionnels de santé qui bravent l'avi...
#
#                                                 Journal  \
# Date_reco
# 2021-07-06                      Le Figaro, no. 23910
# 2020-12-08                                  Le Monde
# 2020-10-15                                l'Humanité
# 2020-11-14   Aujourd'hui en France  Edition Principale
# 2020-11-13                                Libération
# ...                                                 ...
# 2021-01-12                       La Croix, no. 41907
# 2021-02-15   Aujourd'hui en France  Edition Principale
# 2021-03-12                                Libération
# 2021-02-05   Aujourd'hui en France  Edition Principale
# 2021-04-10                      Le Figaro, no. 23837
#
#                                                       Contenu  \
# Date_reco
# 2021-07-06    Le 16 janvier, pour sauver son père de l'asp...
# 2020-12-08    Le Covid-19 a révélé l'extraordinaire potent...
# 2020-10-15    Le traitement médiatique de l'épidémie de Co...
# 2020-11-14    Par Nicolas Berrod, Ludwig Gallet et Paméla ...
# 2020-11-13    Deux personnes masquées, avec des logos de l...
# ...                                                       ...
# 2021-01-12    Depuis 2011 et l'ouverture de la plateforme ...
# 2021-02-15    Par Marcelo Wesfreid   C'était il y a pile u...
# 2021-03-12    Infectiologue de renom, mais guère connu du ...
# 2021-02-05    Elsa Mari et Florence Méréo   L'innovation  ...
# 2021-04-10     CONTINUER à injecter le vaccin AstraZeneca ...
#
#                                                   Auteur
# Date_reco
# 2021-07-06                                Jeantet, Diane
# 2020-12-08                                 Gilbert Deray
# 2020-10-15                                          None
# 2020-11-14                            N.B., L.G. et P.R.
# 2020-11-13           Par ROBIN ANDRACA et VINCENT COQUAZ
# ...                                                  ...
# 2021-01-12                                          None
# 2021-02-15                                          None
# 2021-03-12  Samantha Rouchard Correspondance à Marseille
# 2021-02-05                                 E.M. et Fl.M.
# 2021-04-10                                   Roy, Soline
#
# [206 rows x 5 columns]

# %% [markdown]
# #### Sauvegarder

# %%
corpus.to_csv("Data/Corpus.csv")

# %% [markdown]
# #### Analyser

# %%
corpus["Titre"].resample("w").count().plot()
# Out:
# <AxesSubplot:xlabel='Date_reco'>
